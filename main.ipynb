# %%
def split_into_chunks(doc_file: str) -> list[str]:
    try:
        # 指定 encoding='utf-8' 是处理文档的基操，防止乱码或报错
        with open(doc_file, 'r', encoding='utf-8') as file:
            content = file.read()
        
        # 使用 split 拆分并过滤掉空块（防止文档末尾有多个换行）
        return [chunk.strip() for chunk in content.split("\n\n") if chunk.strip()]
    
    except FileNotFoundError:
        print(f"错误：找不到文件 '{doc_file}'，请检查路径。")
        return []

# 调用测试
chunks = split_into_chunks("doc.md")

for i, chunk in enumerate(chunks):
    print(f"Chunk {i} ")
    print(f"{chunk}\n")
# Out:
# Chunk 0
# # 海马大战喵喵喵：深海秘境与灵猫部族的终极对决
#
# Chunk 1
# # 第一章：秘境缘起——深蓝海域与喵喵森林的边界纠葛
#
# Chunk 2
# 在蔚蓝无垠的深海腹地，藏着一片名为“琉璃海马域”的神秘水域，这里是深海海马族群的世代栖息地。这片海域水质澄澈透亮，水下遍布发光珊瑚与珍珠礁，海水温度常年恒定在适宜生存的区间，孕育了数以万计的黄金海马、冰晶海马、烈焰海马等珍稀族群。海马族群奉行和平共生的法则，由年长且智慧的深海海马王统领，族群擅长操控水流、净化海水，守护着深海秘境的生态平衡，千百年来从未主动与外界发生冲突，始终过着与世无争的生活。
#
# Chunk 3
# 与琉璃海马域隔海相望的，是一片漂浮在海面之上的“云顶喵喵森林”，这片森林由千年灵木构建，枝叶繁茂、终年不散雾气，是喵喵喵部族的家园。喵喵喵部族并非普通猫咪，而是修炼千年的灵猫族群，通体覆盖柔软绒毛，眼眸自带星辰光泽，擅长攀爬、隐匿、释放幻术，还能操控林间风元素。部族由九尾灵猫族长执掌，生性傲娇且领地意识极强，认为海面及周边空域皆为自己的专属领地，对深海族群的存在始终抱有戒备之心，觉得海马族群的水流波动会扰乱森林的灵气运转。
#
# Chunk 4
# 矛盾的导火索，源于一场突如其来的海域异动。深海海底的上古灵珠发生能量外泄，强大的水流冲击力席卷了海面，导致云顶喵喵森林的边缘灵木折断、雾气紊乱，部分幼崽灵猫被水流波及受伤。喵喵喵部族误以为是海马族群故意发动攻击，破坏森林安宁，当即集结精锐兵力，奔赴海岸边界发起对峙；而海马族群则觉得灵珠异动是自然天象，并非族群本意，喵喵喵部族的指责毫无道理，双方各执一词，误会不断加深，和平的局面彻底被打破，一场大战一触即发。
#
# Chunk 5
# # 第二章：战前筹备——双方族群的战力部署与战术谋划
#
# Chunk 6
# 海马族群得知喵喵喵部族即将进犯后，迅速召开族群议事大会，深海海马王召集各分支首领，制定周密的防御与反击战术。黄金海马分支擅长群体协作，负责组建防御阵型，利用发光珊瑚构建水下屏障，阻挡灵猫的幻术侵袭；冰晶海马分支掌控低温能力，可冻结海面表层水流，限制灵猫的移动范围；烈焰海马分支虽数量稀少，却能释放温和的热能光束，用于破解幻术、击退近身的灵猫士兵。同时，海马族群还启动了秘境的守护阵法，将琉璃海马域的入口隐匿，只留下一处狭窄通道作为攻防枢纽。
#
# Chunk 7
#
# Chunk 15
# # 第四章：误会化解——和平共处的最终结局
#
# Chunk 16
# 上古灵珠缓缓浮出水面，投射出一段光影影像，清晰还原了灵珠异动的全过程：原来是海底地壳轻微运动，触发了灵珠的能量外泄，并非海马族群操控水流，更不是故意攻击喵喵森林。影像还展示了双方族群守护家园的初心，海马族群守护深海生态，喵喵喵部族守护森林安宁，本质上都是为了守护这片海域的平衡，并无真正的仇恨。
#
# Chunk 17
# 看到这段影像，九尾灵猫族长瞬间面露愧色，意识到自己误会了海马族群，贸然发动战争是鲁莽之举。深海海马王也主动游向海面，释放出友好的水流信号，表示愿意帮助修复喵喵森林的受损灵木，共同稳定灵珠的能量，避免类似的误会再次发生。灵猫们纷纷收起利爪，放下戒备，海马族群也解散了防御阵型，战场的紧张氛围彻底消散，取而代之的是和解的暖意。
#
# Chunk 18
# 战后，海马族群派出擅长治愈的冰晶海马，用纯净的海水滋养喵喵森林的折断灵木，帮助灵木快速复苏；喵喵喵部族则利用风元素，吹散海域中多余的雾气，让琉璃海马域的水质更加澄澈。双方还签订了和平契约，约定定期互通消息，共同守护海域与森林的生态平衡，遇到自然异象时携手应对，不再轻易发动战争。
#
# Chunk 19
# 自此，深海海马族群与喵喵喵部族从对手变成了挚友，琉璃海马域与云顶喵喵森林之间，再也没有边界冲突。每当阳光洒向海面，总能看到海马在水下欢快游动，灵猫在林间悠闲嬉戏，两大族群和谐共生，谱写了一段跨越海陆的和平佳话，也让这片秘境变得更加安宁美好。
# > （注：文档部分内容可能由 AI 生成）

# %%
from typing import List
from sentence_transformers import SentenceTransformer

# 初始化嵌入模型：使用的是专门针对中文优化的 text2vec 模型
embedding_model = SentenceTransformer("shibing624/text2vec-base-chinese")

def embed_chunk(chunk: str) -> List[float]:
    # 将文本编码为向量（通常返回的是 numpy 数组）
    embedding = embedding_model.encode(chunk)
    # 转换为 Python 原生列表以便后续处理或存储
    return embedding.tolist()

# 测试
test_embedding = embed_chunk("测试内容")
print(len(test_embedding))  # 输出向量的维度
print(test_embedding)       # 输出具体的数值列表
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: shibing624/text2vec-base-chinese
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 768
# [0.5059825778007507, 0.15822024643421173, 0.006481734570115805, 0.13777674734592438, 1.0255964994430542, -1.0052624940872192, 0.025775814428925514, -0.024882743135094643, -0.6929633021354675, 1.3568466901779175, -0.13724206387996674, -0.13313378393650055, 0.8028535842895508, -0.6937482953071594, -1.0334761142730713, -0.18118226528167725, 0.32288578152656555, 1.1165881156921387, -0.6295170783996582, 1.1774250268936157, -0.09227586537599564, -0.6519712805747986, -1.3982642889022827, 0.8347373604774475, 0.19851867854595184, -0.699884831905365, -0.5102170705795288, 0.7230226397514343, 0.40172985196113586, -0.22295452654361725, -0.10209590196609497, 0.05019238963723183, -0.43978622555732727, 1.0002614259719849, 0.09720122069120407, 0.5591888427734375, -0.5815660357475281, -0.33705422282218933, 0.8012154698371887, -0.14520077407360077, -0.2008056491613388, 0.6060848236083984, -1.2443996667861938, -0.22841791808605194, 0.12863363325595856, -0.02180097997188568, -0.3931470811367
852892100811005, 0.5156617164611816, 0.3585933744907379, -0.1668585240840912, -0.07154789566993713, 0.0339982844889164, 0.15791697800159454, 0.5850399732589722, -0.9289953708648682, -0.5255943536758423, 0.3605007231235504, 0.28258422017097473, -0.16153083741664886, 0.48287105560302734, -0.7647804021835327, 0.4164005219936371, -0.0005647936486639082, -0.011050987057387829, -0.0018368506571277976, 0.3749573528766632, -0.26492932438850403, 0.2672893702983856, -0.8399884104728699, -0.3118632733821869, 0.2741140127182007, 0.0027321672532707453, 0.4286767840385437, -0.1465780884027481, 0.2196424901485443, -1.0337917804718018, -0.37389886379241943, 0. ...

# %%
import chromadb
chromadb_client = chromadb.EphemeralClient()
chromadb_collection = chromadb_client.get_or_create_collection(name="default")

def save_embeddings(chunks: List[str], embeddings: List[List[float]]) -> None:
    ids = [str(i) for i in range(len(chunks))]
    chromadb_collection.add(
        documents=chunks,
        embeddings=embeddings,
        ids=ids
    )

save_embeddings(chunks, embeddings)

# %%
def retrieve(query: str, top_k: int) -> List[str]:
    query_embedding = embed_chunk(query)
    results = chromadb_collection.query(
        query_embeddings=[query_embedding],
        n_results=top_k
    )
    return results['documents'][0]

query = "喵喵喵的三个小队分别是什么？"
retrieved_chunks = retrieve(query, 5)

for i, chunk in enumerate(retrieved_chunks):
    print(f"[{i}] {chunk}\n")
# Out:
# [0] 另一边，喵喵喵部族也在紧锣密鼓地筹备战事。九尾灵猫族长挑选出身手敏捷、幻术精湛的精锐灵猫，分为三支小队：突袭小队负责从空中俯冲，突破海马的水流屏障；幻术小队负责在后方释放迷幻雾气，干扰海马的判断与协作；后勤小队则携带疗伤草药与灵气果实，随时支援前线伤员。灵猫们梳理毛发、磨利爪牙，在云顶森林的高台集结，族长站在最高处发表战前宣言，激励部族成员守护家园，彻底击退“入侵”的海马族群，夺回被扰乱的领地灵气。
#
# [1] 与琉璃海马域隔海相望的，是一片漂浮在海面之上的“云顶喵喵森林”，这片森林由千年灵木构建，枝叶繁茂、终年不散雾气，是喵喵喵部族的家园。喵喵喵部族并非普通猫咪，而是修炼千年的灵猫族群，通体覆盖柔软绒毛，眼眸自带星辰光泽，擅长攀爬、隐匿、释放幻术，还能操控林间风元素。部族由九尾灵猫族长执掌，生性傲娇且领地意识极强，认为海面及周边空域皆为自己的专属领地，对深海族群的存在始终抱有戒备之心，觉得海马族群的水流波动会扰乱森林的灵气运转。
#
# [2] 海马族群得知喵喵喵部族即将进犯后，迅速召开族群议事大会，深海海马王召集各分支首领，制定周密的防御与反击战术。黄金海马分支擅长群体协作，负责组建防御阵型，利用发光珊瑚构建水下屏障，阻挡灵猫的幻术侵袭；冰晶海马分支掌控低温能力，可冻结海面表层水流，限制灵猫的移动范围；烈焰海马分支虽数量稀少，却能释放温和的热能光束，用于破解幻术、击退近身的灵猫士兵。同时，海马族群还启动了秘境的守护阵法，将琉璃海马域的入口隐匿，只留下一处狭窄通道作为攻防枢纽。
#
# [3] 自此，深海海马族群与喵喵喵部族从对手变成了挚友，琉璃海马域与云顶喵喵森林之间，再也没有边界冲突。每当阳光洒向海面，总能看到海马在水下欢快游动，灵猫在林间悠闲嬉戏，两大族群和谐共生，谱写了一段跨越海陆的和平佳话，也让这片秘境变得更加安宁美好。
# > （注：文档部分内容可能由 AI 生成）
#
# [4] 看到这段影像，九尾灵猫族长瞬间面露愧色，意识到自己误会了海马族群，贸然发动战争是鲁莽之举。深海海马王也主动游向海面，释放出友好的水流信号，表示愿意帮助修复喵喵森林的受损灵木，共同稳定灵珠的能量，避免类似的误会再次发生。灵猫们纷纷收起利爪，放下戒备，海马族群也解散了防御阵型，战场的紧张氛围彻底消散，取而代之的是和解的暖意。

# %%
from sentence_transformers import CrossEncoder

def rerank(query: str, retrieved_chunks: List[str], top_k: int) -> List[str]:
    cross_encoder = CrossEncoder('cross-encoder/mmarco-mMiniLMv2-L12-H384-v1')
    pairs = [(query, chunk) for chunk in retrieved_chunks]
    scores = cross_encoder.predict(pairs)

    chunk_with_score_list = [(chunk, score)
                             for chunk, score in zip(retrieved_chunks, scores)]
    chunk_with_score_list.sort(key=lambda pair: pair[1], reverse=True)

    return [chunk for chunk, _ in chunk_with_score_list][:top_k]

reranked_chunks = rerank(query, retrieved_chunks, 3)

for i, chunk in enumerate(reranked_chunks):
    print(f"[{i}] {chunk}\n")
# Out:
# config.json:   0%|          | 0.00/891 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# XLMRobertaForSequenceClassification LOAD REPORT from: cross-encoder/mmarco-mMiniLMv2-L12-H384-v1
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# [0] 另一边，喵喵喵部族也在紧锣密鼓地筹备战事。九尾灵猫族长挑选出身手敏捷、幻术精湛的精锐灵猫，分为三支小队：突袭小队负责从空中俯冲，突破海马的水流屏障；幻术小队负责在后方释放迷幻雾气，干扰海马的判断与协作；后勤小队则携带疗伤草药与灵气果实，随时支援前线伤员。灵猫们梳理毛发、磨利爪牙，在云顶森林的高台集结，族长站在最高处发表战前宣言，激励部族成员守护家园，彻底击退“入侵”的海马族群，夺回被扰乱的领地灵气。
#
# [1] 海马族群得知喵喵喵部族即将进犯后，迅速召开族群议事大会，深海海马王召集各分支首领，制定周密的防御与反击战术。黄金海马分支擅长群体协作，负责组建防御阵型，利用发光珊瑚构建水下屏障，阻挡灵猫的幻术侵袭；冰晶海马分支掌控低温能力，可冻结海面表层水流，限制灵猫的移动范围；烈焰海马分支虽数量稀少，却能释放温和的热能光束，用于破解幻术、击退近身的灵猫士兵。同时，海马族群还启动了秘境的守护阵法，将琉璃海马域的入口隐匿，只留下一处狭窄通道作为攻防枢纽。
#
# [2] 与琉璃海马域隔海相望的，是一片漂浮在海面之上的“云顶喵喵森林”，这片森林由千年灵木构建，枝叶繁茂、终年不散雾气，是喵喵喵部族的家园。喵喵喵部族并非普通猫咪，而是修炼千年的灵猫族群，通体覆盖柔软绒毛，眼眸自带星辰光泽，擅长攀爬、隐匿、释放幻术，还能操控林间风元素。部族由九尾灵猫族长执掌，生性傲娇且领地意识极强，认为海面及周边空域皆为自己的专属领地，对深海族群的存在始终抱有戒备之心，觉得海马族群的水流波动会扰乱森林的灵气运转。

# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()
google_client = genai.Client()

def generate(query: str, chunks: list[str]) -> str:
    prompt = f"""你是一位知识助手，请根据用户的问题和下列片段生成准确的回答。

用户问题：{query}

相关片段：
{"\n\n".join(chunks)}

请基于上述内容作答，不要编造信息。"""

    print(f"{prompt}\n\n---\n")

    response = google_client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
answer=generate(query,reranked_chunks)
print(answer)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 2
#       1 from dotenv import load_dotenv
# ----> 2 from google import genai
#       4 load_dotenv()
#       5 google_client = genai.Client()
#
# ImportError: cannot import name 'genai' from 'google' (unknown location)

# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()
google_client = genai.Client()

def generate(query: str, chunks: list[str]) -> str:
    prompt = f"""你是一位知识助手，请根据用户的问题和下列片段生成准确的回答。

用户问题：{query}

相关片段：
{"\n\n".join(chunks)}

请基于上述内容作答，不要编造信息。"""

    print(f"{prompt}\n\n---\n")

    response = google_client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
answer=generate(query,reranked_chunks)
print(answer)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 from dotenv import load_dotenv
# ----> 2 from google import genai
#       4 load_dotenv()
#       5 google_client = genai.Client()
#
# ImportError: cannot import name 'genai' from 'google' (unknown location)

# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()
google_client = genai.Client()

def generate(query: str, chunks: list[str]) -> str:
    prompt = f"""你是一位知识助手，请根据用户的问题和下列片段生成准确的回答。

用户问题：{query}

相关片段：
{"\n\n".join(chunks)}

请基于上述内容作答，不要编造信息。"""

    print(f"{prompt}\n\n---\n")

    response = google_client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
answer=generate(query,reranked_chunks)
print(answer)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 from dotenv import load_dotenv
# ----> 2 from google import genai
#       4 load_dotenv()
#       5 google_client = genai.Client()
#
# ImportError: cannot import name 'genai' from 'google' (unknown location)

# %%
from dotenv import load_dotenv
from google import genai
client = genai.Client(api_key="AIzaSyCv0Xu5RCK17nXPut8yPkBPk2Zno-EenBE")

load_dotenv()
google_client = genai.Client()

def generate(query: str, chunks: list[str]) -> str:
    prompt = f"""你是一位知识助手，请根据用户的问题和下列片段生成准确的回答。

用户问题：{query}

相关片段：
{"\n\n".join(chunks)}

请基于上述内容作答，不要编造信息。"""

    print(f"{prompt}\n\n---\n")

    response = google_client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
answer=generate(query,reranked_chunks)
print(answer)
# Out:
# 你是一位知识助手，请根据用户的问题和下列片段生成准确的回答。
#
# 用户问题：喵喵喵的三个小队分别是什么？
#
# 相关片段：
# 另一边，喵喵喵部族也在紧锣密鼓地筹备战事。九尾灵猫族长挑选出身手敏捷、幻术精湛的精锐灵猫，分为三支小队：突袭小队负责从空中俯冲，突破海马的水流屏障；幻术小队负责在后方释放迷幻雾气，干扰海马的判断与协作；后勤小队则携带疗伤草药与灵气果实，随时支援前线伤员。灵猫们梳理毛发、磨利爪牙，在云顶森林的高台集结，族长站在最高处发表战前宣言，激励部族成员守护家园，彻底击退“入侵”的海马族群，夺回被扰乱的领地灵气。
#
# 海马族群得知喵喵喵部族即将进犯后，迅速召开族群议事大会，深海海马王召集各分支首领，制定周密的防御与反击战术。黄金海马分支擅长群体协作，负责组建防御阵型，利用发光珊瑚构建水下屏障，阻挡灵猫的幻术侵袭；冰晶海马分支掌控低温能力，可冻结海面表层水流，限制灵猫的移动范围；烈焰海马分支虽数量稀少，却能释放温和的热能光束，用于破解幻术、击退近身的灵猫士兵。同时，海马族群还启动了秘境的守护阵法，将琉璃海马域的入口隐匿，只留下一处狭窄通道作为攻防枢纽。
#
# 与琉璃海马域隔海相望的，是一片漂浮在海面之上的“云顶喵喵森林”，这片森林由千年灵木构建，枝叶繁茂、终年不散雾气，是喵喵喵部族的家园。喵喵喵部族并非普通猫咪，而是修炼千年的灵猫族群，通体覆盖柔软绒毛，眼眸自带星辰光泽，擅长攀爬、隐匿、释放幻术，还能操控林间风元素。部族由九尾灵猫族长执掌，生性傲娇且领地意识极强，认为海面及周边空域皆为自己的专属领地，对深海族群的存在始终抱有戒备之心，觉得海马族群的水流波动会扰乱森林的灵气运转。
#
# 请基于上述内容作答，不要编造信息。
#
# ---
#
# 喵喵喵部族的三个小队分别是：
#
# 1.  **突袭小队**：负责从空中俯冲，突破海马的水流屏障。
# 2.  **幻术小队**：负责在后方释放迷幻雾气，干扰海马的判断与协作。
# 3.  **后勤小队**：携带疗伤草药与灵气果实，随时支援前线伤员。

# %%
def retrieve(query: str, top_k: int) -> List[str]:
    query_embedding = embed_chunk(query)
    results = chromadb_collection.query(
        query_embeddings=[query_embedding],
        n_results=top_k
    )
    return results['documents'][0]

query = "喵喵喵有几队？"
retrieved_chunks = retrieve(query, 5)

from sentence_transformers import CrossEncoder

def rerank(query: str, retrieved_chunks: List[str], top_k: int) -> List[str]:
    cross_encoder = CrossEncoder('cross-encoder/mmarco-mMiniLMv2-L12-H384-v1')
    pairs = [(query, chunk) for chunk in retrieved_chunks]
    scores = cross_encoder.predict(pairs)

    chunk_with_score_list = [(chunk, score)
                             for chunk, score in zip(retrieved_chunks, scores)]
    chunk_with_score_list.sort(key=lambda pair: pair[1], reverse=True)

    return [chunk for chunk, _ in chunk_with_score_list][:top_k]

reranked_chunks = rerank(query, retrieved_chunks, 3)
from dotenv import load_dotenv
from google import genai
client = genai.Client(api_key="AIzaSyCv0Xu5RCK17nXPut8yPkBPk2Zno-EenBE")

load_dotenv()
google_client = genai.Client()

def generate(query: str, chunks: list[str]) -> str:
    prompt = f"""你是一位知识助手，请根据用户的问题和下列片段生成准确的回答。

用户问题：{query}

相关片段：
{"\n\n".join(chunks)}

请基于上述内容作答，不要编造信息。"""

    print(f"{prompt}\n\n---\n")

    response = google_client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text
answer=generate(query,reranked_chunks)
print(answer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       7     return results['documents'][0]
#       9 query = "喵喵喵有几队？"
# ---> 10 retrieved_chunks = retrieve(query, 5)
#      12 from sentence_transformers import CrossEncoder
#      14 def rerank(query: str, retrieved_chunks: List[str], top_k: int) -> List[str]:
#
# Cell In[1], line 2, in retrieve(query, top_k)
#       1 def retrieve(query: str, top_k: int) -> List[str]:
# ----> 2     query_embedding = embed_chunk(query)
#       3     results = chromadb_collection.query(
#       4         query_embeddings=[query_embedding],
#       5         n_results=top_k
#       6     )
#       7     return results['documents'][0]
#
# NameError: name 'embed_chunk' is not defined
